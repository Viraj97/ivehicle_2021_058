# %% [markdown]
# ## Create the dictionary file for labels (first from A-Z and then from a-)

# %%
f = open('deps.txt')
lines = f.read().splitlines()
f.close()

deps_dict = {}
counter = 65
for dep in lines:
    deps_dict[dep.replace(' ', '').lower()] = chr(counter)
    if(counter == 90):
        counter = 97
    else:
        counter += 1

# deprecated labels to be taken care of
deps_dict['npadvmod'] = 'b'
deps_dict['nmod'] = 'a'
print(deps_dict)
# Out:
# {'acl': 'A', 'acomp': 'B', 'advcl': 'C', 'advmod': 'D', 'agent': 'E', 'amod': 'F', 'appos': 'G', 'attr': 'H', 'aux': 'I', 'auxpass': 'J', 'case': 'K', 'cc': 'L', 'ccomp': 'M', 'compound': 'N', 'conj': 'O', 'csubj': 'P', 'csubjpass': 'Q', 'dative': 'R', 'dep': 'S', 'det': 'T', 'dobj': 'U', 'expl': 'V', 'intj': 'W', 'mark': 'X', 'meta': 'Y', 'neg': 'Z', 'nounmod': 'a', 'npmod': 'b', 'nsubj': 'c', 'nsubjpass': 'd', 'nummod': 'e', 'oprd': 'f', 'parataxis': 'g', 'pcomp': 'h', 'pobj': 'i', 'poss': 'j', 'preconj': 'k', 'predet': 'l', 'prep': 'm', 'prt': 'n', 'punct': 'o', 'quantmod': 'p', 'relcl': 'q', 'root': 'r', 'xcomp': 's', 'npadvmod': 'b', 'nmod': 'a'}

# %% [markdown]
# ## Sample produce a sentence code

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("I am going out with my family.")

sent_struct = []
for token in doc:
    sent_struct.append(deps_dict[token.dep_.lower()])

sentence_code = ''.join(sent_struct)
print(sentence_code)
# Out:
# cIrnmjio

# %%
def encode_sentence(english):
    doc = nlp(english)

    sent_struct = []
    for token in doc:
        sent_struct.append(deps_dict[token.dep_.lower()])

    sentence_code = ''.join(sent_struct)
    return sentence_code

# %% [markdown]
# ## First, create a dictionary of the sentence codes (with their occurences)

# %%
import nltk
nltk.download('perluniprops')
from nltk.corpus import brown
from nltk.tokenize.moses import MosesDetokenizer
mdetok = MosesDetokenizer()
# Out:
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.

# %%
nltk.download('brown')
sentence_code_dict = {}

for book in brown.fileids():
    for sent in brown.sents(book):
        munged_sentence = ' '.join(sent).replace('``', '"').replace("''", '"').replace('`', "'")
        payload = nlp(mdetok.detokenize(munged_sentence.split(), return_str=True))
        sent_struct = []
        for token in payload:
            sent_struct.append(deps_dict[token.dep_.lower()])
    
        sentence_code = ''.join(sent_struct)
        #print(payload.text)
        #print(sentence_code)
        #print('--')
        if sentence_code in sentence_code_dict:
            sentence_code_dict[sentence_code] += 1
        else:
            sentence_code_dict[sentence_code] = 1

# print(sentence_code_dict)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
custom_sentence = 'Ronaldo has been the most consistent performer today.'
payload = nlp(custom_sentence)
sent_struct = []
for token in payload:
    sent_struct.append(deps_dict[token.dep_.lower()])
sentence_code = ''.join(sent_struct)
print(sentence_code)
if sentence_code in sentence_code_dict:
    sentence_code_dict[sentence_code] += 1
else:
    sentence_code_dict[sentence_code] = 1
# Out:
# cIrTDFHbo

# %%
sentence_code_dict['TcIrmTio']
# Out:
# 2

# %% [markdown]
# ## Now this dictionary needs to be written to file (both as npy and text file)

# %%
f = open('sentence_codes.txt', 'w')

for key, value in sentence_code_dict.items():
    f.write(key + ' ' + str(value) + '\n')

f.close()

import numpy as np
np.save('sentence_correction_dict.npy', sentence_code_dict)

# %% [markdown]
# ## Watch sentence correction in action

# %%
# !pip install sympound
# Out:
# Collecting sympound
#   Downloading sympound-0.6.0.tar.gz (6.9 kB)
# Building wheels for collected packages: sympound
#   Building wheel for sympound (setup.py) ... done
#   Created wheel for sympound: filename=sympound-0.6.0-py3-none-any.whl size=6558 sha256=c46bfc1d222e8c12a9645d207ece804ff4772e763db0290eb851b104a5403d26
#   Stored in directory: /root/.cache/pip/wheels/6e/cb/4b/b41189400a9756d29ee2795a9ea36acfa7d5878c263d7adc1f
# Successfully built sympound
# Installing collected packages: sympound
# Successfully installed sympound-0.6.0

# %%
# !pip install pyxdameraulevenshtein
# Out:
# Collecting pyxdameraulevenshtein
#   Downloading pyxDamerauLevenshtein-1.7.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pyxdameraulevenshtein
#   Building wheel for pyxdameraulevenshtein (PEP 517) ... done
#   Created wheel for pyxdameraulevenshtein: filename=pyxDamerauLevenshtein-1.7.0-cp37-cp37m-linux_x86_64.whl size=65597 sha256=edeff562d5486b67bf7d648d87a5a9db186aecea30261f6069f5713aabf2e8c0
#   Stored in directory: /root/.cache/pip/wheels/68/33/62/4dda096670bdf4bf505ed05cc8566f02c7184ae77d081a31df
# Successfully built pyxdameraulevenshtein
# Installing collected packages: pyxdameraulevenshtein
# Successfully installed pyxdameraulevenshtein-1.7.0

# %%
import os

import numpy as np
from sympound import sympound

import platform
distancefun = None
if platform.system() != "Windows":
    from pyxdameraulevenshtein import damerau_levenshtein_distance
    distancefun = damerau_levenshtein_distance
else:
    from jellyfish import levenshtein_distance
    distancefun = levenshtein_distance


ssc = sympound(distancefun=distancefun, maxDictionaryEditDistance=3)

def test():
    #ssc.create_dictionary_entry("bonjour", 1) # optional, only if adding dictionary items is required
    
    sc_dict = np.load('sentence_correction_dict.npy',allow_pickle=True ).item()
    
    ssc.load_dictionary("sentence_codes.txt", term_index=0, count_index=1)
    payload = encode_sentence('Ronaldo has been most consistent performer on today.')
    
    if payload in sc_dict:
        print('correct!')
        return
    
    try:
        #result = ssc.lookup_compound(input_string=payload, edit_distance_max=1) # choose edit_distance carefully
        result = ssc.lookup(input_string=payload, verbosity=0, edit_distance_max=1) # choose edit_distance carefully
    except TypeError:
        print('no matches!')
        return
    
    if(result == []):
        return
    
    print(result[-1])
    result = str(result[-1]).split(':')
    print('wrong :      ' + payload)
    print('correction : ' + result[0])
    print('position : ' + result[2])
    
    ssc.save_pickle("symspell.pickle")
    #ssc.load_pickle("symspell.pickle")

test()
# Out:
# cIrDTHmio:1:1
# wrong :      cIrDFHmio
# correction : cIrDTHmio
# position : 1

# %% [markdown]
# ## Decode the encoded sentence structure string

# %%
f = open('deps.txt')
lines = f.read().splitlines()
f.close()

inv_deps_dict = {}
counter = 65
for dep in lines:
    inv_deps_dict[chr(counter)] = dep.replace(' ', '').lower()
    if(counter == 90):
        counter = 97
    else:
        counter += 1

# deprecated labels to be taken care of
inv_deps_dict['b'] = 'npadvmod'
inv_deps_dict['a'] = 'nmod'
print(inv_deps_dict)
# Out:
# {'A': 'acl', 'B': 'acomp', 'C': 'advcl', 'D': 'advmod', 'E': 'agent', 'F': 'amod', 'G': 'appos', 'H': 'attr', 'I': 'aux', 'J': 'auxpass', 'K': 'case', 'L': 'cc', 'M': 'ccomp', 'N': 'compound', 'O': 'conj', 'P': 'csubj', 'Q': 'csubjpass', 'R': 'dative', 'S': 'dep', 'T': 'det', 'U': 'dobj', 'V': 'expl', 'W': 'intj', 'X': 'mark', 'Y': 'meta', 'Z': 'neg', 'a': 'nmod', 'b': 'npadvmod', 'c': 'nsubj', 'd': 'nsubjpass', 'e': 'nummod', 'f': 'oprd', 'g': 'parataxis', 'h': 'pcomp', 'i': 'pobj', 'j': 'poss', 'k': 'preconj', 'l': 'predet', 'm': 'prep', 'n': 'prt', 'o': 'punct', 'p': 'quantmod', 'q': 'relcl', 'r': 'root', 's': 'xcomp'}

# %%
def decode_coding(code):
    code_list = list(code.replace(' ', ''))
    decoded_list = []
    for char in code_list:
        decoded_list.append(inv_deps_dict[char])
    return decoded_list

# %%
mycode = 'TcIIrmTio'
decode_coding(mycode)
# Out:
# ['det', 'nsubj', 'aux', 'aux', 'root', 'prep', 'det', 'pobj', 'punct']

# %%
def correct():
    # ssc.create_dictionary_entry("bonjour", 1) # optional, only if adding dictionary items is required
    
    sc_dict = np.load('/content/sentence_correction_dict.npy',allow_pickle=True).item()
    
    ssc.load_dictionary("sentence_codes.txt", term_index=0, count_index=1)
    payload = encode_sentence('Ronaldo has been most consistent performer in today.')
    
    if payload in sc_dict:
        print('correct!')
        return
    
    try:
        #result = ssc.lookup_compound(input_string=payload, edit_distance_max=1) # choose edit_distance carefully
        result = ssc.lookup(input_string=payload, verbosity=0, edit_distance_max=1) # choose edit_distance carefully
    except TypeError:
        print('no matches!')
        return
    
    if(result == []):
        return
    
    print(result[-1])
    result = str(result[-1]).split(':')
    print('wrong :      ' + payload)
    print('correction : ' + result[0])
    #print('position : ' + result[2])
    
    correct_broke = list(result[0])
    wrong_broke = list(payload)
    
    ssc.save_pickle("symspell.pickle")
    #ssc.load_pickle("symspell.pickle")

correct()
# Out:
# cIrDTHmio:0:1
# wrong :      cIrDFHmio
# correction : cIrDTHmio

# %% [markdown]
# ## Comparing strings and finding out the exact error

# %%
correct = list('cIFrTDFHboT')
wrong = list('cIrDFHboT')
wrong, common = wrong[:], [ e for e in correct if e in wrong and (wrong.pop(wrong.index(e)) or True)]
common
# Out:
# ['c', 'I', 'F', 'r', 'T', 'D', 'H', 'b', 'o']

# %%
x = ['1', '2', '3', '4']
x.pop(3)
# Out:
# '4'

# %%
x
# Out:
# ['1', '2', '3']
